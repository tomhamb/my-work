# %%
sleep_rating=7

# %%
print(sleep_rating)
# Out:
# 7

# %%
ice_cream_rating=8

# %%
print(ice_cream_rating)
# Out:
# 8

# %%
first_name=Tom
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 first_name=Tom
#
# NameError: name 'Tom' is not defined

# %%
first_name="Tom"

# %%
last_name="Hambling"

# %%
print(first_name,last_name)
# Out:
# Tom Hambling

# %%
import math

# %%
happiness_rating=(8+7)/2

# %%
print(happiness_rating)
# Out:
# 7.5

# %%
type(happiness_rating)
# Out:
# float

# %%
type(ice_cream_rating)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 type(ice_cream_rating)
#
# NameError: name 'ice_cream_rating' is not defined

# %%
type(sleep_rating)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 type(sleep_rating)
#
# NameError: name 'sleep_rating' is not defined

# %%
print(ice_cream_rating)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(ice_cream_rating)
#
# NameError: name 'ice_cream_rating' is not defined

# %%
sleep_rating=7

# %%
type(sleep_rating)
# Out:
# int

# %%
print(type(sleep_rating,happiness_rating))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(type(sleep_rating,happiness_rating))
#
# TypeError: type() takes 1 or 3 arguments

# %%
my_name=(first_name,last_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 my_name=(first_name,last_name)
#
# NameError: name 'first_name' is not defined

# %%
first_name="Tom "

# %%
last_name="Hambling"

# %%
my_name=(first_name+last_name)

# %%
print(my_name)
# Out:
# Tom Hambling

# %%
type(my_name)
# Out:
# str

# %%
print(ice_cream_rating,sleep_rating,happiness_rating)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 print(ice_cream_rating,sleep_rating,happiness_rating)
#
# NameError: name 'ice_cream_rating' is not defined

# %%
ice_cream_rating=8

# %%
sleep_rating=7

# %%
happiness_rating=(sleep_rating+ice_cream_rating)/2

# %%
print(ice_cream_rating,sleep_rating,happiness_rating)
# Out:
# 8 7 7.5

# %%
first_name="Tom"

# %%
last_name="Hambling"

# %%
my_name=first_name+" "+last_name

# %%
print(my_name)
# Out:
# Tom Hambling

# %%
first_line_1="My name is"

# %%
first_line_2="and I give eating ice cream a score of"

# %%
first_line_3="out of 10!"

# %%
print(first_line_1,first_name,first_line_2,ice_cream_rating,first_line_3)
# Out:
# My name is Tom and I give eating ice cream a score of 8 out of 10!

# %%
second_line_1="I am"

# %%
second_line_2="and my sleeping enjoyment rating is"

# %%
second_line_3="/10!"

# %%
print(second_line_1,my_name,second_line_2,sleep_rating,second_line_3)
# Out:
# I am Tom Hambling and my sleeping enjoyment rating is 7 /10!

# %%
third_line_1="Based on the factors above, my happiness rating is"

# %%
third_line_2="out of 10, or"

# %%
happiness_percentage="75%!"

# %%
print(third_line_1,happiness_rating,third_line_2,happiness_percentage)
# Out:
# Based on the factors above, my happiness rating is 7.5 out of 10, or 75%!
